# %%
# Initialize your data again for this new file
ENGINEER = "RIVERA"# Your surname
STUDENT_ID = "TUPM-25-0084" # Your ID
SEED_NUM = int(STUDENT_ID[-1])  # Calculate seed again (e.g., 4)

# --- NOW THE EXERCISE CODE WILL WORK ---

target_name = ENGINEER
redacted_name = ""

print(f"Original Surname: {target_name}")

for char in target_name:
    if char in "AEIOU":
        redacted_name += str(SEED_NUM)
    else:
        redacted_name += char

print(f"Redacted Output: {redacted_name}")
# Out:
# Original Surname: RIVERA
# Redacted Output: R4V4R4

# %%
ENGINEER = "RIVERA"
STUDENT_ID = "TUPM-25-0084"
SEED_NUM = int(STUDENT_ID[-1])
first_letter = ENGINEER[0]
ascii_value = ord(first_letter)

total_loops = SEED_NUM * ascii_value

verification_hash = (ascii_value * SEED_NUM) - total_loops

print(f"Verification Hash: {verification_hash}")
print(f"ASCII Value of '{first_letter}': {ascii_value}")
print(f"Total Loops: {total_loops}")
print(f"SEED_NUM: {SEED_NUM}")
# Out:
# Verification Hash: 0
# ASCII Value of 'R': 82
# Total Loops: 328
# SEED_NUM: 4

# %%
#[appendinx exercise 3] secure system gate

correct_password = "CHINESE NEWYEAR"
attempts = 1

print("--- SYSTEM LOCKED ---")

while True:
    user_pass = input("Enter Passowrd:")
    print(f"\n>> ACCESS GRANTED. Welcome, {ENGINEER}!")
    print(f"\n>> Total Attempts Before Success:{attempts}")
    break
else:
    print(">> Access Denied. Try Again.")

print("n-- ASSESSMENT DATA FOR EXERCISE 3")
print(f"Correct Password Set: {correct_password}")
print(f"Attempts before Success: {attempts}")
# Out:
# --- SYSTEM LOCKED ---
#
# >> ACCESS GRANTED. Welcome, RIVERA!
#
# >> Total Attempts Before Success:1
# n-- ASSESSMENT DATA FOR EXERCISE 3
# Correct Password Set: CHINESE NEWYEAR
# Attempts before Success: 1
